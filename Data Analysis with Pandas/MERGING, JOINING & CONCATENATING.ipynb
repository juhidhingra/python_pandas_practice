# %%
import pandas as pd

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %% [markdown]
# # concat method is called directly on pandas library

# %% [markdown]
# # THE pd.concat() method

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
sales_total = pd.concat([week1,week2],ignore_index=True,sort=False)

# %%
sales_total
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %% [markdown]
# # using keys will create a mutli index data frame so that we can identify where exactly the data is coming from- like below - week and week 2

# %%
sales = pd.concat([week1,week2],keys=["week1","week2"])

# %%
sales
# Out:
#            Customer ID  Food ID
# week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
#       5            213        8
#       6            600        1
#       7            503        5
#       8             71        3
#       9            174        3
#       10           961        9
#       11           966        5
#       12           641        4
#       13           288        2
#       14           149        4
#       15           954        2
#       16           147        9
#       17           155        1
#       18           550        6
#       19           101        7
#       20           549        6
#       21            75        6
#       22            78        7
#       23           514        5
#       24           833        7
#       25           329        8
#       26           586       10
#       27           341        1
# ...

# %%
sales.loc[("week1")]
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
sales.iloc[(0)]
# Out:
# Customer ID    537
# Food ID          9
# Name: (week1, 0), dtype: int64

# %% [markdown]
# # append is same like concat method - only difference - that append is called directly on a data frame while concat is called directly on pandas

# %%
append_sales = week2.append(week1, ignore_index=True)

# %%
append_sales
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 470          147        8
# 471          745        4
# 472          184        3
# ...

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %% [markdown]
# # INNER JOIN - ONLY THE OVERLAPPED DATA SETS WILL BE INCLUDED -THE POINT WHERE THEY HAVE COMMON VALUES IS INNER JOIN

# %%
week1.merge(week2,how="inner",on="Customer ID", suffixes=["- week1","- week2"]).head()
# Out:
#    Customer ID  Food ID- week1  Food ID- week2
# 0          537               9               5
# 1          155               9               3
# 2          155               1               3
# 3          503               5               8
# 4          503               5               9

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# # represents the customers who came in both weeks and got the exact same item each time m

# %%
week1.merge(week2, how="inner",on = ["Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %% [markdown]
# # combine rows that have common values using outer join

# %%
merged =week1.merge(week2,how="outer",on = "Customer ID",suffixes=["- week1","-week2"],indicator=True)

# %%
len(week1.merge(week2,how="outer",on = "Customer ID",suffixes=["- week1","-week2"],indicator=True))
# Out:
# 454

# %% [markdown]
# # there are 46 rows found in both data frames that was able to match the customer id together- ie.46 customer id found in both that had common values

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
merged_data = merged["_merge"].isin(["left_only","right_only"])

# %%
merged_data
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6       True
# 7       True
# 8      False
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22     False
# 23      True
# 24     False
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 424     True
# 425     True
# 426     True
# 427     True
# 428     True
# 429     True
# 430     True
# 431     True
# 432     True
# 433     True
# 434     True
# 435     True
# 436     True
# 437     True
# 438     True
# 439     True
# 440     True
# 441     True
# 442     True
# 443     True
# 444     True
# 445     True
# 446     True
# 447     True
# 448     True
# 449     True
# 450     True
# 451     True
# 452     True
# 453     True
# Name: _merge, Length: 454, dtype: bool

# %% [markdown]
# # TO FIND VALUES IN COMMON - INNER JOIN
# # TO FIND VALUES IN EITHER DATA FRAME OR BOTH - OUTER JOIN
# # TO FIND VALUES IN EITHER DATA FRAME BUT NOT BOTH - FULL OUTER JOIN
# # THEN EXTRACT THAT CENTER COMPONENT BY USING INDICATOR TO REMOVE VALUES THAT ARE BOTH

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1[week1["Customer ID"] == 21]
# Out:
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
week2[week2["Customer ID"] == 21]
# Out:
#     Customer ID  Food ID
# 30           21        4

# %% [markdown]
# # performs very similar to a vlookup operation - LEFT JOIN

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1 = week1.merge(foods,how="left",on="Food ID",sort=True).head()

# %%
week1.head()
# Out:
#    Customer ID  Food ID Food Item_x  Price_x Food Item_y  Price_y
# 0          658        1       Sushi     3.99       Sushi     3.99
# 1          600        1       Sushi     3.99       Sushi     3.99
# 2          155        1       Sushi     3.99       Sushi     3.99
# 3          341        1       Sushi     3.99       Sushi     3.99
# 4           20        1       Sushi     3.99       Sushi     3.99

# %% [markdown]
# # if we dont have the exact same column names - THE LEFT_ON AND RIGHT_ON PARAMETERS

# %% [markdown]
# # ON PARAMETER - ONLY AVAILABLE IF WE HAVE THE EXACT SAME COLUMN NAMES IN BOTH THE DATA SETS

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2.merge(customers,how="left", left_on="Customer ID",right_on="ID",sort=True).drop("ID",axis="columns")
# Out:
#      Customer ID  Food ID   First Name  Last Name  Gender        Company  \
# 0              8        6      Frances      Adams  Female       Dabshots
# 1             13        2         Ruth    Alvarez  Female    Twitterlist
# 2             21        4       Albert      Burns    Male      Rhynoodle
# 3             24        8        Donna     Thomas  Female        Jaxbean
# 4             27        4      Jessica    Bennett  Female  Twitternation
# 5             30        4       Pamela      Hicks  Female          Ntags
# 6             35        8       Nicole    Chapman  Female        Pixonyx
# 7             39       10       Teresa   Harrison  Female            Oba
# 8             45        8         Earl   Marshall    Male          Agivu
# 9             46        6         Adam       Cole    Male          Trupe
# 10            54        8       Amanda      Berry  Female        Jaxspan
# 11            55        9        Ralph       Ford    Male     Browsezoom
# ...

# %% [markdown]
# # MERGING by INDEXES ON RIGHT_INDEX AND LEFT_INDEX

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv",index_col="ID")
foods = pd.read_csv("Restaurant - Foods.csv",index_col="Food ID")

# %%
customers.head(3)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %% [markdown]
# # advantage of merging on index - DUPLICATE COLUMNS DONT ARISE

# %%
sales = week1.merge(customers, how="left",left_on="Customer ID",right_index=True)

# %%
sales.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
# 3          202        2      Louis  Campbell    Male  Rhynoodle
# 4          155        9    Carolyn      Diaz  Female   Gigazoom
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist
# 3     Account Representative III
# 4     Database Administrator III

# %% [markdown]
# # EXAMPLE 2:

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv",index_col="ID")
foods = pd.read_csv("Restaurant - Foods.csv",index_col="Food ID")

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist

# %%
sales.merge(foods, how ="left", left_on= "Food ID",right_index=True)
# Out:
#      Customer ID  Food ID First Name  Last Name  Gender       Company  \
# 0            537        9     Cheryl    Carroll  Female      Zoombeat
# 1             97        4     Amanda    Watkins  Female           Ozu
# 2            658        1    Patrick       Webb    Male     Browsebug
# 3            202        2      Louis   Campbell    Male     Rhynoodle
# 4            155        9    Carolyn       Diaz  Female      Gigazoom
# 5            213        8      Keith     Foster    Male     Gigashots
# 6            600        1     Sandra     Bailey  Female     Jaxnation
# 7            503        5     Justin    Daniels    Male          Oloo
# 8             71        3    Carolyn      Reyes  Female        Twimbo
# 9            174        3       Anna     Miller  Female       Innojam
# 10           961        9      Ralph   Richards    Male  Thoughtstorm
# 11           966        5     Robert       Ford    Male    Jabbertype
# ...

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2,how="left",left_index=True,right_index=True,suffixes=[" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# ...

# %% [markdown]
# # THE JOIN() METHOD

# %% [markdown]
# # CONCATENATE TWO DATA FRAME WITH THE EXACT SAME INDEX

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction =pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
satisfaction.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction =pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %% [markdown]
# # PD.MERGE() METHOD

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
pd.merge(week1, customers, how = "left", left_on= "Customer ID", right_on="ID",sort=True).head()
# Out:
#    Customer ID  Food ID  ID First Name Last Name  Gender    Company  \
# 0            3        2   3      Roger     Black    Male    Tagfeed
# 1           10        2  10     Steven      Ryan    Male    Twinder
# 2           20        1  20       Lisa      Rice  Female       Oloo
# 3           21        4  21     Albert     Burns    Male  Rhynoodle
# 4           21        4  21     Albert     Burns    Male  Rhynoodle
#
#                       Occupation
# 0              Account Executive
# 1  Community Outreach Specialist
# 2                  Programmer IV
# 3               Junior Executive
# 4               Junior Executive
